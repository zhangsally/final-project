# %% [markdown]
# ## City Of Pittsburgh Parks
#
# ### Links to Datasets:
# 1. [Parks Dataset](https://data.wprdc.org/dataset/parks1/resource/bb57d0a7-e8ee-4218-8906-0dedc903038c?inner_span=True)
# 2. [Neighborhoods Dataset](https://data.wprdc.org/dataset/neighborhoods2)
#
# ### Metric: Environment and Accessibility
#
# Neighborhoods with parks enjoy a myriad of benefits that significantly enhance residents' quality of life. Parks serve as communal hubs, fostering social connections and a sense of community, while also providing spaces for physical activities that promote both physical and mental well-being. My metric is Envirement/accessibility we will use this metric to figure out what neighborhoods have the most parks.
#
# # Data Exploration

# %% [markdown]
# First we see what neighborhood has the most amount of parks. The more Parks means the more accessibility for the community making it a better place. We will take the top 10 for parks and see which neighborhood has the most parks.

# %%
import pandas as pd

# Load Parks CSV
parks_df = pd.read_csv('Parks.csv')

# Filter rows where 'type' is 'Park'
parks_df = parks_df[parks_df['type'] == 'Park']

# Group the DataFrame by neighborhood and count the number of parks in each neighborhood
neighborhood_park_counts = parks_df['neighborhood'].value_counts()

# Find the top 10 neighborhoods with the most parks
top_10_neighborhoods = neighborhood_park_counts.head(10).index

# Create a DataFrame with the top 10 neighborhoods and the maximum number of parks in each neighborhood
top_10_parks_df = pd.DataFrame({'neighborhood': top_10_neighborhoods, 'max_parks': neighborhood_park_counts[top_10_neighborhoods]})

# Randomize the order of the 'neighborhood' column in the top 10 parks DataFrame
top_10_parks_df = top_10_parks_df.sample(frac=1).reset_index(drop=True)

# Display all information for the top 10 neighborhoods with the most parks
result_df = pd.merge(parks_df, top_10_parks_df, on='neighborhood')
result_df
# Out:
#     _id          id                                         name  type  \
# 0     1  2111959181                               Able Long Park  Park
# 1     8  1829922263                                   Alton Park  Park
# 2    23  1990832198  Beechview Healthy Active Living Center Park  Park
# 3   151  1572177418                                 Pauline Park  Park
# 4   182  1504989458                                Tropical Park  Park
# 5   186  1952724428                                 Vanucci Park  Park
# 6    11  1928748922                               Arlington Park  Park
# 7    37   712782057                           Cobden Street Park  Park
# 8    55   303472511                          Eleanor Street Park  Park
# 9   132   375307767                             Monongahela Park  Park
# 10  171   353743875                               Southside Park  Park
# 11  204   821363109                                 Winters Park  Park
# 12   24  2099892727                            Blair Street Park  Park
# 13   31   276671370                              Bud Hammer Park  Park
# 14   33  1398444262                                 Burgwin Park  Park
# 15   83   504093825                               Gladstone Park  Park
# 16  109   289174231                                   Lewis Park  Park
# 17   27  1591249432                        Brighton Heights Park  Park
# 18  105  1992246196                         Legion Memorial Park  Park
# 19  119   572257490                               Marmaduke Park  Park
# 20   38  2113503545                                  Cowley Park  Park
# 21   80  1730609241                                 Gardner Park  Park
# 22  113  1595333980                          Lookout Street Park  Park
# 23  183  1233709867                     Troy Hill Citizen's Park  Park
# 24  194  2137736333                    Washington's Landing Park  Park
# 25   52   210545055                            East Liberty Park  Park
# 26   65  1066215150                                 Enright Park  Park
# 27   81   148492759                                 Garland Park  Park
# 28  208  1719897212                           Liberty Green Park  Park
# 29   60   919254688       Emerald View Park - Grandview Overlook  Park
# 30   61   255934841      Emerald View Park - Mt. Washington Park  Park
# 31   62   983437605             Emerald View Park - Olympia Park  Park
# 32   63  1599043610                Emerald View Park - Ream Park  Park
# 33   64  1783038748       Emerald View Park - Shiloh Street Park  Park
# 34   91   159173801                                Herschel Park  Park
# 35  181  1643702639                                Townsend Park  Park
# 36  195   660130896                                West End Park  Park
# 37  197  1849203338               West End-Elliott Overlook Park  Park
# 38  120  1665484106                     Marshall-California Park  Park
# 39  193   691951672                         Washburn Square Park  Park
# 40  205  1460363095                               Woods Run Park  Park
# 41  206   930068146                             Young Field Park  Park
# 42  124  1318913796                               McGonigle Park  Park
# 43  136  2001007242                                  Mutual Park  Park
# 44  168  1064478922                                Sheraden Park  Park
# 45  185  1460991055                     Tuxedo Street Skate Park  Park
#
#    maintenance_responsibility  \
# 0            Parks - Southern
# 1            Parks - Southern
# 2            Parks - Southern
# 3            Parks - Southern
# 4            Parks - Southern
# 5            Parks - Southern
# 6            Parks - Southern
# 7            Parks - Southern
# 8            Parks - Southern
# 9            Parks - Southern
# 10           Parks - Southern
# 11           Parks - Southern
# 12           Parks - Schenley
# 13           Parks - Schenley
# 14            Parks - Eastern
# 15            Parks - Eastern
# 16            Parks - Eastern
# 17           Parks - Northern
# 18           Parks - Northern
# 19           Parks - Northern
# 20           Parks - Northern
# 21           Parks - Northern
# 22           Parks - Northern
# 23           Parks - Northern
# 24           Parks - Northern
# 25            Parks - Eastern
# 26          Parks - Northeast
# 27          Parks - Northeast
# 28          Parks - Northeast
# 29            Parks - Western
# 30            Parks - Western
# 31            Parks - Western
# 32            Parks - Western
# 33            Parks - Western
# 34            Parks - Western
# 35            Parks - Western
# 36            Parks - Western
# 37            Parks - Western
# 38           Parks - Northern
# 39           Parks - Northern
# 40           Parks - Northern
# 41           Parks - Northern
# 42            Parks - Western
# 43            Parks - Western
# 44            Parks - Western
# 45            Parks - Western
#
#                                                 image        neighborhood  \
# 0   https://tools.wprdc.org/images/pittsburgh/park...           Beechview
# 1                                                 NaN           Beechview
# 2                                                 NaN           Beechview
# 3                                                 NaN           Beechview
# 4   https://tools.wprdc.org/images/pittsburgh/park...           Beechview
# 5                                                 NaN           Beechview
# 6                                                 NaN   South Side Slopes
# 7                                                 NaN   South Side Slopes
# 8                                                 NaN   South Side Slopes
# 9                                                 NaN   South Side Slopes
# 10                                                NaN   South Side Slopes
# 11                                                NaN   South Side Slopes
# 12                                                NaN           Hazelwood
# 13                                                NaN           Hazelwood
# 14  https://tools.wprdc.org/images/pittsburgh/park...           Hazelwood
# 15  https://tools.wprdc.org/images/pittsburgh/park...           Hazelwood
# 16                                                NaN           Hazelwood
# 17                                                NaN    Brighton Heights
# 18  https://tools.wprdc.org/images/pittsburgh/park...    Brighton Heights
# 19  https://tools.wprdc.org/images/pittsburgh/park...    Brighton Heights
# 20  https://tools.wprdc.org/images/pittsburgh/park...           Troy Hill
# 21                                                NaN           Troy Hill
# 22  https://tools.wprdc.org/images/pittsburgh/park...           Troy Hill
# 23  https://tools.wprdc.org/images/pittsburgh/park...           Troy Hill
# 24                                                NaN           Troy Hill
# 25                                                NaN        East Liberty
# 26                                                NaN        East Liberty
# 27                                                NaN        East Liberty
# 28                                                NaN        East Liberty
# 29                                                NaN    Mount Washington
# 30                                                NaN    Mount Washington
# 31                                                NaN    Mount Washington
# 32                                                NaN    Mount Washington
# 33                                                NaN    Mount Washington
# 34                                                NaN             Elliott
# 35  https://tools.wprdc.org/images/pittsburgh/park...             Elliott
# 36                                                NaN             Elliott
# 37                                                NaN             Elliott
# 38  https://tools.wprdc.org/images/pittsburgh/park...  Marshall-Shadeland
# 39  https://tools.wprdc.org/images/pittsburgh/park...  Marshall-Shadeland
# 40  https://tools.wprdc.org/images/pittsburgh/park...  Marshall-Shadeland
# 41                                                NaN  Marshall-Shadeland
# 42                                                NaN            Sheraden
# 43                                                NaN            Sheraden
# 44  https://tools.wprdc.org/images/pittsburgh/park...            Sheraden
# 45  https://tools.wprdc.org/images/pittsburgh/park...            Sheraden
#
#     council_district  ward        tract  public_works_division  pli_division  \
# 0                  4    19  42003192000                      5            19
# 1                  4    19  42003191600                      5            19
# 2                  4    19  42003191600                      5            19
# 3                  4    19  42003192000                      5            19
# 4                  4    19  42003191600                      5            19
# 5                  4    19  42003191600                      5            19
# 6                  3    16  42003160800                      3            16
# 7                  3    16  42003160800                      3            16
# 8                  3    16  42003160800                      3            16
# 9                  3    16  42003160800                      3            16
# 10                 3    17  42003160800                      3            17
# 11                 3    17  42003170600                      3            17
# 12                 5    15  42003562900                      3            15
# 13                 5    15  42003562900                      3            15
# 14                 5    15  42003562300                      3            15
# 15                 5    15  42003562300                      3            15
# 16                 5    15  42003562900                      3            15
# 17                 1    27  42003270800                      1            27
# 18                 1    27  42003270100                      1            27
# 19                 1    27  42003270100                      1            27
# 20                 1    24  42003240600                      1            24
# 21                 1    24  42003240600                      1            24
# 22                 1    24  42003240600                      1            24
# 23                 1    24  42003240600                      1            24
# 24                 1    24  42003240600                      6            24
# 25                 9    11  42003111500                      2            11
# 26                 9     8  42003111500                      2             8
# 27                 9    11  42003111500                      2            11
# 28                 9    11  42003111500                      2            11
# 29                 2    19  42003190300                      5            19
# 30                 2    19  42003191400                      5            19
# 31                 2    19  42003190300                      5            19
# 32                 2    19  42003190300                      5            19
# 33                 2    19  42003191400                      5            19
# 34                 2    20  42003562600                      5            20
# 35                 2    20  42003562600                      5            20
# 36                 2    20  42003562600                      5            20
# 37                 2    20  42003562600                      5            20
# 38                 1    27  42003270400                      1            27
# 39                 1    27  42003270400                      1            27
# 40                 1    27  42003271500                      1            27
# 41                 1    27  42003271500                      1            27
# 42                 2    20  42003202200                      5            20
# 43                 2    20  42003202200                      5            20
# 44                 2    20  42003562500                      5            20
# 45                 2    20  42003202200                      5            20
#
#     police_zone fire_zone   latitude  longitude  max_parks
# 0             6      4-28  40.408118 -80.028197          6
# 1             6      4-28  40.414580 -80.021855          6
# 2             6      4-28  40.410721 -80.024362          6
# 3             6      4-28  40.404576 -80.025946          6
# 4             6      4-28  40.422261 -80.023991          6
# 5             6      4-28  40.414811 -80.017843          6
# 6             3      4-22  40.418283 -79.975050          6
# 7             3      4-22  40.419338 -79.968198          6
# 8             3      4-22  40.421408 -79.972879          6
# 9             3      4-22  40.421699 -79.966333          6
# 10            3      4-22  40.420951 -79.977412          6
# 11            3       4-3  40.422667 -79.981445          6
# 12            4      2-13  40.403974 -79.945672          5
# 13            4      2-12  40.420954 -79.946695          5
# 14            4      2-13  40.404445 -79.936834          5
# 15            4      2-12  40.415146 -79.938607          5
# 16            4      2-13  40.412894 -79.944810          5
# 17            1      1-14  40.485600 -80.029606          3
# 18            1      1-14  40.481883 -80.034712          3
# 19            1      1-14  40.484649 -80.042966          3
# 20            1       1-2  40.458690 -79.988924          5
# 21            1       1-2  40.461699 -79.986260          5
# 22            1       1-2  40.469293 -79.976931          5
# 23            1       1-2  40.463227 -79.983715          5
# 24            1       1-1  40.468755 -79.973822          5
# 25            5      3-10  40.462065 -79.918745          4
# 26            5      3-23  40.461885 -79.929833          4
# 27            5       3-8  40.463949 -79.927637          4
# 28            5      3-10  40.462773 -79.919314          4
# 29            3      4-27  40.432901 -80.008521          5
# 30            3      4-27  40.422810 -80.015455          5
# 31            3       4-1  40.430995 -80.018361          5
# 32            3      4-27  40.430974 -80.013246          5
# 33            3      4-27  40.431417 -80.006742          5
# 34            6      1-17  40.439462 -80.043455          4
# 35            6      1-17  40.443063 -80.040150          4
# 36            6      1-17  40.436713 -80.037092          4
# 37            6      1-17  40.446332 -80.033703          4
# 38            1       1-9  40.462518 -80.030594          4
# 39            1      1-14  40.467056 -80.031151          4
# 40            1      1-14  40.476383 -80.029253          4
# 41            1      1-14  40.472963 -80.032768          4
# 42            6      1-16  40.459298 -80.066199          4
# 43            6      1-16  40.451985 -80.064161          4
# 44            6      1-16  40.458651 -80.059786          4
# 45            6      1-16  40.453366 -80.066516          4

# %%
import pandas as pd

# Load Parks CSV
parks_df = pd.read_csv('Parks.csv')

# Filter rows where 'type' is 'Park'
parks_df = parks_df[parks_df['type'] == 'Park']

# Group the DataFrame by neighborhood and count the number of parks in each neighborhood
neighborhood_park_counts = parks_df['neighborhood'].value_counts()

# Find the top 10 neighborhoods with the most parks
top_10_neighborhoods = neighborhood_park_counts.head(10).index

# Create a DataFrame with the top 10 neighborhoods and the maximum number of parks in each neighborhood
top_10_parks_df = pd.DataFrame({'neighborhood': top_10_neighborhoods, 'max_parks': neighborhood_park_counts[top_10_neighborhoods]})

# Sort the DataFrame by the number of parks in descending order
top_10_parks_df = top_10_parks_df.sort_values(by='max_parks', ascending=False).reset_index(drop=True)

# Use groupby to get unique mapping of neighborhoods to longitude and latitude
neighborhood_coords = parks_df.groupby('neighborhood')[['longitude', 'latitude']].first()

# Merge with top_10_parks_df
top_10_parks_df = pd.merge(top_10_parks_df, neighborhood_coords, left_on='neighborhood', right_index=True)

# Display the result using .head()
top_10_parks_df.head(10)
# Out:
#          neighborhood  max_parks  longitude   latitude
# 0           Beechview          6 -80.028197  40.408118
# 1   South Side Slopes          6 -79.975050  40.418283
# 2           Troy Hill          5 -79.988924  40.458690
# 3           Hazelwood          5 -79.945672  40.403974
# 4    Mount Washington          5 -80.008521  40.432901
# 5             Elliott          4 -80.043455  40.439462
# 6            Sheraden          4 -80.066199  40.459298
# 7  Marshall-Shadeland          4 -80.030594  40.462518
# 8        East Liberty          4 -79.918745  40.462065
# 9    Brighton Heights          3 -80.029606  40.485600

# %% [markdown]
# Now before we map these parks and make a bar graph i'll add the neighborhoods with 0 parks. These neighborhoods will lack a communal social envirement for their neighborhood dropping them from the best neighborhoods.

# %%
import pandas as pd

neighborhood_df = pd.read_csv('neighborhoods.csv')

# Load Parks CSV
parks_df = pd.read_csv('Parks.csv')

# Merge the two dataframes on the common column
merged_df = pd.merge(neighborhood_df, parks_df, left_on='hood', right_on='neighborhood', how='left')

# Create a new column indicating whether the neighborhood has a park or not
merged_df['has_park'] = merged_df['name'].notnull()

# Separate into two sets
neighborhoods_with_parks = merged_df[merged_df['has_park'] == True]
neighborhoods_without_parks = merged_df[merged_df['has_park'] == False]

# Display or save the results
print("Neighborhoods without Parks:")
print(neighborhoods_without_parks[['hood', 'neighborhood']])
# Out:
# Neighborhoods without Parks:
#                      hood neighborhood
# 8               Knoxville          NaN
# 15             Glen Hazel          NaN
# 36      Northview Heights          NaN
# 39      Arlington Heights          NaN
# 68         Allegheny West          NaN
# 86              Overbrook          NaN
# 87             Friendship          NaN
# 99         East Allegheny          NaN
# 118        Chartiers City          NaN
# 160             Ridgemont          NaN
# 166           South Shore          NaN
# 167            Mt. Oliver          NaN
# 168  California-Kirkbride          NaN
# 187             St. Clair          NaN
# 188               Chateau          NaN
# 189             Shadyside          NaN
# 190           Summer Hill          NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Parks CSV
parks_df = pd.read_csv('Parks.csv')

# Filter rows where 'type' is 'Park'
parks_df = parks_df[parks_df['type'] == 'Park']

# Group the DataFrame by neighborhood and count the number of parks in each neighborhood
neighborhood_park_counts = parks_df['neighborhood'].value_counts()

# Find the top 10 neighborhoods with the most parks
top_10_neighborhoods = neighborhood_park_counts.head(10)

# Create a bar graph directly from the DataFrame
top_10_neighborhoods.plot(kind='bar', color='skyblue')
plt.title('Top 10 Neighborhoods with the Most Parks')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Parks')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
import geopandas as gpd

# Load neighborhood GeoDataFrame from the same directory
neighborhood_map = gpd.read_file("NeighborhoodMap/Neighborhoods_.shp")

# Plot the neighborhood map
neighborhood_map.plot()
